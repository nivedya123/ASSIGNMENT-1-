# %%
import numpy as np  #numbers , mathematical opertions 
import pandas as pd #data manipulations
import seaborn as sns #statistical analysis

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#ASSIGNMENT QUESTION 1 ANSWER
#ques : plot a line between a  and   b
a=np.arange(40,50)
b=np.arange(50,60)

plt.xlabel(" a  " , color="blue")
plt.ylabel("b " , color="blue")

plt.plot(a,b ,color="red")

# %%
#ASSIGNMENT QUESTION 2 ANSWER

#ques : Plot a line plot showing the sales trens in company 1 and 2

days=[1,2,3,4,5,6,7]#days of a week
sales_1=[160,150,140,145,175,165,180]#sales of company 1
sales_2=[70,90,160,150,140,145,175]#sales of company 1

plt.xlabel("days of a week" ,color="red")
plt.ylabel("sales",color="red")
plt.plot(x,y,color="orange")
plt.plot(z,color="green")
plt.show()

# %%
##ASSIGNMENT QUESTION 3 ANSWER

#ques : create a 3 by subplots 
x=[1,2,3,4]
y1=[4,3,2,1]
y2=[10,20,30,40]
y3=[40,30,20,10]
y4=[1,2,1,2]
y5=[40,70,90,70]
plt.title("SUB PLOTS")

plt.subplot(3,3,1)
plt.plot(x,y1,"r--")

plt.subplot(3,3,2)
plt.plot(x,y2,"g--")

plt.subplot(3,3,3)
plt.plot(x,y3,"b--")

plt.subplot(3,3,4)
plt.plot(x,y4,"y--")

plt.subplot(3,3,5)
plt.plot(x,y5,"v--")
 
plt.show()
